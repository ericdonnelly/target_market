# %% [markdown]
# # IMPORT DEPENDENCIES

# %%
import os
import pandas as pd
from pandas.io.json import json_normalize
from pandas import DataFrame
import numpy as np
import geopandas as gpd
from shapely import wkt
from shapely.wkt import loads
import re
from config import gkey
import json
import google_streetview.api
import streetview
import time
import glob
import itertools 
import urllib.request

# %% [markdown]
# # geojson files from openaddresses https://openaddresses.io/

# %%
# Pull in geojson address data from openaddresses
fname = "resources/us_il_city_of_evanston-addresses-city.geojson"

# read file to dataframe
gdf = gpd.read_file(fname)

simpledec = re.compile(r"\d*\.\d+")
def mround(match):
    return "{:.5f}".format(float(match.group()))

gdf.geometry = gdf.geometry.apply(lambda x: loads(re.sub(simpledec, mround, x.wkt)))
gdf
# Out:
#       id unit number       street      city district region postcode  \
# 0                811  CHICAGO AVE  EVANSTON              IL    60202
# 1               2730   CENTRAL ST  EVANSTON              IL    60201
# 2               2726   CENTRAL ST  EVANSTON              IL    60201
# 3               2720   CENTRAL ST  EVANSTON              IL    60201
# 4               2722   CENTRAL ST  EVANSTON              IL    60201
# ...   ..  ...    ...          ...       ...      ...    ...      ...
# 17130           1122   PITNER AVE  EVANSTON              IL    60202
# 17131           1124   PITNER AVE  EVANSTON              IL    60202
# 17132           1514    DEWEY AVE  EVANSTON              IL    60201
# 17133           1141    DEWEY AVE  EVANSTON              IL    60202
# 17134           1141   DARROW AVE  EVANSTON              IL    60202
#
#                    hash                    geometry
# 0      0f1ae9d6dc3e261d  POINT (-87.67892 42.03261)
# 1      04d8292c6fe41f75  POINT (-87.71218 42.06420)
# 2      0f6aa09515f2553f  POINT (-87.71201 42.06420)
# 3      a9c1519f7bce1807  POINT (-87.71154 42.06419)
# 4      48834904e3e1b801  POINT (-87.71182 42.06420)
# ...                 ...                         ...
# 17130  a06c3531387e9893  POINT (-87.70577 42.03833)
# 17131  30eaae035c012e54  POINT (-87.70577 42.03839)
# 17132  c5f8058ef65e857f  POINT (-87.69672 42.04531)
# 17133  ba9fd44f5993932b  POINT (-87.69571 42.03897)
# 17134  ed8c3c1a7f027a5c  POINT (-87.69728 42.03903)
#
# [17135 rows x 10 columns]

# %% [markdown]
# # Create Pandas dataframe from geopandas dataframe

# %%
# Verify/Make pandas dataframe
addressdf = pd.DataFrame(gdf)

# Change 'geometry' column datatype from geometry to object
addressdf['geometry'] = addressdf.geometry.apply(lambda x: wkt.dumps(x, rounding_precision=5))

# %%
# Check dataframe
addressdf
# Out:
#       id unit number       street      city district region postcode  \
# 0                811  CHICAGO AVE  EVANSTON              IL    60202
# 1               2730   CENTRAL ST  EVANSTON              IL    60201
# 2               2726   CENTRAL ST  EVANSTON              IL    60201
# 3               2720   CENTRAL ST  EVANSTON              IL    60201
# 4               2722   CENTRAL ST  EVANSTON              IL    60201
# ...   ..  ...    ...          ...       ...      ...    ...      ...
# 17130           1122   PITNER AVE  EVANSTON              IL    60202
# 17131           1124   PITNER AVE  EVANSTON              IL    60202
# 17132           1514    DEWEY AVE  EVANSTON              IL    60201
# 17133           1141    DEWEY AVE  EVANSTON              IL    60202
# 17134           1141   DARROW AVE  EVANSTON              IL    60202
#
#                    hash                    geometry
# 0      0f1ae9d6dc3e261d  POINT (-87.67892 42.03261)
# 1      04d8292c6fe41f75  POINT (-87.71218 42.06420)
# 2      0f6aa09515f2553f  POINT (-87.71201 42.06420)
# 3      a9c1519f7bce1807  POINT (-87.71154 42.06419)
# 4      48834904e3e1b801  POINT (-87.71182 42.06420)
# ...                 ...                         ...
# 17130  a06c3531387e9893  POINT (-87.70577 42.03833)
# 17131  30eaae035c012e54  POINT (-87.70577 42.03839)
# 17132  c5f8058ef65e857f  POINT (-87.69672 42.04531)
# 17133  ba9fd44f5993932b  POINT (-87.69571 42.03897)
# 17134  ed8c3c1a7f027a5c  POINT (-87.69728 42.03903)
#
# [17135 rows x 10 columns]

# %%
# Combine address columns to one column
# addressdf['address'] = addressdf['street'].str.cat(addressdf['city'].str.cat(addressdf['region'],sep=" ")

# Remove extra strings from the latitude and longitude in the geometry column
addressdf['geometry'] = addressdf['geometry'].str.replace('POINT ', '').str.replace('(', '').str.replace(')', '')
addressdf
# Out:
#       id unit number       street      city district region postcode  \
# 0                811  CHICAGO AVE  EVANSTON              IL    60202
# 1               2730   CENTRAL ST  EVANSTON              IL    60201
# 2               2726   CENTRAL ST  EVANSTON              IL    60201
# 3               2720   CENTRAL ST  EVANSTON              IL    60201
# 4               2722   CENTRAL ST  EVANSTON              IL    60201
# ...   ..  ...    ...          ...       ...      ...    ...      ...
# 17130           1122   PITNER AVE  EVANSTON              IL    60202
# 17131           1124   PITNER AVE  EVANSTON              IL    60202
# 17132           1514    DEWEY AVE  EVANSTON              IL    60201
# 17133           1141    DEWEY AVE  EVANSTON              IL    60202
# 17134           1141   DARROW AVE  EVANSTON              IL    60202
#
#                    hash            geometry
# 0      0f1ae9d6dc3e261d  -87.67892 42.03261
# 1      04d8292c6fe41f75  -87.71218 42.06420
# 2      0f6aa09515f2553f  -87.71201 42.06420
# 3      a9c1519f7bce1807  -87.71154 42.06419
# 4      48834904e3e1b801  -87.71182 42.06420
# ...                 ...                 ...
# 17130  a06c3531387e9893  -87.70577 42.03833
# 17131  30eaae035c012e54  -87.70577 42.03839
# 17132  c5f8058ef65e857f  -87.69672 42.04531
# 17133  ba9fd44f5993932b  -87.69571 42.03897
# 17134  ed8c3c1a7f027a5c  -87.69728 42.03903
#
# [17135 rows x 10 columns]

# %%
# Remove un-needed columns
addressdf.drop(['unit', 'district'],axis=1,inplace=True)
addressdf
# Out:
#       id number       street      city region postcode              hash  \
# 0           811  CHICAGO AVE  EVANSTON     IL    60202  0f1ae9d6dc3e261d
# 1          2730   CENTRAL ST  EVANSTON     IL    60201  04d8292c6fe41f75
# 2          2726   CENTRAL ST  EVANSTON     IL    60201  0f6aa09515f2553f
# 3          2720   CENTRAL ST  EVANSTON     IL    60201  a9c1519f7bce1807
# 4          2722   CENTRAL ST  EVANSTON     IL    60201  48834904e3e1b801
# ...   ..    ...          ...       ...    ...      ...               ...
# 17130      1122   PITNER AVE  EVANSTON     IL    60202  a06c3531387e9893
# 17131      1124   PITNER AVE  EVANSTON     IL    60202  30eaae035c012e54
# 17132      1514    DEWEY AVE  EVANSTON     IL    60201  c5f8058ef65e857f
# 17133      1141    DEWEY AVE  EVANSTON     IL    60202  ba9fd44f5993932b
# 17134      1141   DARROW AVE  EVANSTON     IL    60202  ed8c3c1a7f027a5c
#
#                  geometry
# 0      -87.67892 42.03261
# 1      -87.71218 42.06420
# 2      -87.71201 42.06420
# 3      -87.71154 42.06419
# 4      -87.71182 42.06420
# ...                   ...
# 17130  -87.70577 42.03833
# 17131  -87.70577 42.03839
# 17132  -87.69672 42.04531
# 17133  -87.69571 42.03897
# 17134  -87.69728 42.03903
#
# [17135 rows x 8 columns]

# %% [markdown]
# # Switch Lat/Long to correct position

# %%
def format_coordinates(x):
    coordinates = x.split(' ')
    lat = str(coordinates[1])
    long = str(coordinates[0])
    formatted = lat + ', ' + long
    return formatted
addressdf['geometry'] = addressdf['geometry'].apply(format_coordinates)
addressdf
# Out:
#       id number       street      city region postcode              hash  \
# 0           811  CHICAGO AVE  EVANSTON     IL    60202  0f1ae9d6dc3e261d
# 1          2730   CENTRAL ST  EVANSTON     IL    60201  04d8292c6fe41f75
# 2          2726   CENTRAL ST  EVANSTON     IL    60201  0f6aa09515f2553f
# 3          2720   CENTRAL ST  EVANSTON     IL    60201  a9c1519f7bce1807
# 4          2722   CENTRAL ST  EVANSTON     IL    60201  48834904e3e1b801
# ...   ..    ...          ...       ...    ...      ...               ...
# 17130      1122   PITNER AVE  EVANSTON     IL    60202  a06c3531387e9893
# 17131      1124   PITNER AVE  EVANSTON     IL    60202  30eaae035c012e54
# 17132      1514    DEWEY AVE  EVANSTON     IL    60201  c5f8058ef65e857f
# 17133      1141    DEWEY AVE  EVANSTON     IL    60202  ba9fd44f5993932b
# 17134      1141   DARROW AVE  EVANSTON     IL    60202  ed8c3c1a7f027a5c
#
#                   geometry
# 0      42.03261, -87.67892
# 1      42.06420, -87.71218
# 2      42.06420, -87.71201
# 3      42.06419, -87.71154
# 4      42.06420, -87.71182
# ...                    ...
# 17130  42.03833, -87.70577
# 17131  42.03839, -87.70577
# 17132  42.04531, -87.69672
# 17133  42.03897, -87.69571
# 17134  42.03903, -87.69728
#
# [17135 rows x 8 columns]

# %%
# add comma after City. Format for api call
addressdf['city'] = addressdf['city'].apply(lambda x: f"{x},")
addressdf
# Out:
#       id number       street       city region postcode              hash  \
# 0           811  CHICAGO AVE  EVANSTON,     IL    60202  0f1ae9d6dc3e261d
# 1          2730   CENTRAL ST  EVANSTON,     IL    60201  04d8292c6fe41f75
# 2          2726   CENTRAL ST  EVANSTON,     IL    60201  0f6aa09515f2553f
# 3          2720   CENTRAL ST  EVANSTON,     IL    60201  a9c1519f7bce1807
# 4          2722   CENTRAL ST  EVANSTON,     IL    60201  48834904e3e1b801
# ...   ..    ...          ...        ...    ...      ...               ...
# 17130      1122   PITNER AVE  EVANSTON,     IL    60202  a06c3531387e9893
# 17131      1124   PITNER AVE  EVANSTON,     IL    60202  30eaae035c012e54
# 17132      1514    DEWEY AVE  EVANSTON,     IL    60201  c5f8058ef65e857f
# 17133      1141    DEWEY AVE  EVANSTON,     IL    60202  ba9fd44f5993932b
# 17134      1141   DARROW AVE  EVANSTON,     IL    60202  ed8c3c1a7f027a5c
#
#                   geometry
# 0      42.03261, -87.67892
# 1      42.06420, -87.71218
# 2      42.06420, -87.71201
# 3      42.06419, -87.71154
# 4      42.06420, -87.71182
# ...                    ...
# 17130  42.03833, -87.70577
# 17131  42.03839, -87.70577
# 17132  42.04531, -87.69672
# 17133  42.03897, -87.69571
# 17134  42.03903, -87.69728
#
# [17135 rows x 8 columns]

# %%
##HERO DATA RETURN

addressdf = addressdf.assign(addresses = addressdf.number.astype(str) + " " +\
  addressdf.street.astype(str) + " " + addressdf.city.astype(str) + " " + \
  addressdf.region.astype(str) + " " +addressdf.postcode.astype(str))
addressdf
# Out:
#       id number       street       city region postcode              hash  \
# 0           811  CHICAGO AVE  EVANSTON,     IL    60202  0f1ae9d6dc3e261d
# 1          2730   CENTRAL ST  EVANSTON,     IL    60201  04d8292c6fe41f75
# 2          2726   CENTRAL ST  EVANSTON,     IL    60201  0f6aa09515f2553f
# 3          2720   CENTRAL ST  EVANSTON,     IL    60201  a9c1519f7bce1807
# 4          2722   CENTRAL ST  EVANSTON,     IL    60201  48834904e3e1b801
# ...   ..    ...          ...        ...    ...      ...               ...
# 17130      1122   PITNER AVE  EVANSTON,     IL    60202  a06c3531387e9893
# 17131      1124   PITNER AVE  EVANSTON,     IL    60202  30eaae035c012e54
# 17132      1514    DEWEY AVE  EVANSTON,     IL    60201  c5f8058ef65e857f
# 17133      1141    DEWEY AVE  EVANSTON,     IL    60202  ba9fd44f5993932b
# 17134      1141   DARROW AVE  EVANSTON,     IL    60202  ed8c3c1a7f027a5c
#
#                   geometry                           addresses
# 0      42.03261, -87.67892  811 CHICAGO AVE EVANSTON, IL 60202
# 1      42.06420, -87.71218  2730 CENTRAL ST EVANSTON, IL 60201
# 2      42.06420, -87.71201  2726 CENTRAL ST EVANSTON, IL 60201
# 3      42.06419, -87.71154  2720 CENTRAL ST EVANSTON, IL 60201
# 4      42.06420, -87.71182  2722 CENTRAL ST EVANSTON, IL 60201
# ...                    ...                                 ...
# 17130  42.03833, -87.70577  1122 PITNER AVE EVANSTON, IL 60202
# 17131  42.03839, -87.70577  1124 PITNER AVE EVANSTON, IL 60202
# 17132  42.04531, -87.69672   1514 DEWEY AVE EVANSTON, IL 60201
# 17133  42.03897, -87.69571   1141 DEWEY AVE EVANSTON, IL 60202
# 17134  42.03903, -87.69728  1141 DARROW AVE EVANSTON, IL 60202
#
# [17135 rows x 9 columns]

# %% [markdown]
# # Use to make a small sample of the dataset if needed

# %%
adds_sml = addressdf.sample(n = 10) 
adds_sml
# Out:
#       id number         street       city region postcode              hash  \
# 13971       811      RIDGE TER  EVANSTON,     IL    60201  0a4d353f3dc17987
# 7607        810  WASHINGTON ST  EVANSTON,     IL    60202  d5ad6c46a97bbace
# 11449       235    HARTREY AVE  EVANSTON,     IL    60202  b334c383117110ec
# 560         732      RIDGE AVE  EVANSTON,     IL    60202  5f57b1d0369dd498
# 10514      2141      EWING AVE  EVANSTON,     IL    60201  f534e189976e9f4b
# 15053      1827     BRUMMEL ST  EVANSTON,     IL    60202  0b8421c09c9e5be5
# 4811       1408        LAKE ST  EVANSTON,     IL    60201  f22cc3a32e39cb45
# 2516        944      DODGE AVE  EVANSTON,     IL    60202  60e62fa43d1b4092
# 13448      2307  ORRINGTON AVE  EVANSTON,     IL    60201  c4d202fc76765e20
# 13803       815        REBA PL  EVANSTON,     IL    60202  39079fcdf761871f
#
#                   geometry                              addresses
# 13971  42.06383, -87.68228       811 RIDGE TER EVANSTON, IL 60201
# 7607   42.03249, -87.68292   810 WASHINGTON ST EVANSTON, IL 60202
# 11449  42.02233, -87.70396     235 HARTREY AVE EVANSTON, IL 60202
# 560    42.03143, -87.68647       732 RIDGE AVE EVANSTON, IL 60202
# 10514  42.05691, -87.71263      2141 EWING AVE EVANSTON, IL 60201
# 15053  42.02152, -87.69919     1827 BRUMMEL ST EVANSTON, IL 60202
# 4811   42.04403, -87.69260        1408 LAKE ST EVANSTON, IL 60201
# 2516   42.03531, -87.69974       944 DODGE AVE EVANSTON, IL 60202
# 13448  42.05961, -87.67926  2307 ORRINGTON AVE EVANSTON, IL 60201
# 13803  42.03006, -87.68290         815 REBA PL EVANSTON, IL 60202

# %% [markdown]
# # Create index from property 'id' in the initial data set.

# %%
adds_sml['id'] = adds_sml.index
adds_sml
# Out:
#           id number         street       city region postcode  \
# 13971  13971    811      RIDGE TER  EVANSTON,     IL    60201
# 7607    7607    810  WASHINGTON ST  EVANSTON,     IL    60202
# 11449  11449    235    HARTREY AVE  EVANSTON,     IL    60202
# 560      560    732      RIDGE AVE  EVANSTON,     IL    60202
# 10514  10514   2141      EWING AVE  EVANSTON,     IL    60201
# 15053  15053   1827     BRUMMEL ST  EVANSTON,     IL    60202
# 4811    4811   1408        LAKE ST  EVANSTON,     IL    60201
# 2516    2516    944      DODGE AVE  EVANSTON,     IL    60202
# 13448  13448   2307  ORRINGTON AVE  EVANSTON,     IL    60201
# 13803  13803    815        REBA PL  EVANSTON,     IL    60202
#
#                    hash             geometry  \
# 13971  0a4d353f3dc17987  42.06383, -87.68228
# 7607   d5ad6c46a97bbace  42.03249, -87.68292
# 11449  b334c383117110ec  42.02233, -87.70396
# 560    5f57b1d0369dd498  42.03143, -87.68647
# 10514  f534e189976e9f4b  42.05691, -87.71263
# 15053  0b8421c09c9e5be5  42.02152, -87.69919
# 4811   f22cc3a32e39cb45  42.04403, -87.69260
# 2516   60e62fa43d1b4092  42.03531, -87.69974
# 13448  c4d202fc76765e20  42.05961, -87.67926
# 13803  39079fcdf761871f  42.03006, -87.68290
#
#                                    addresses
# 13971       811 RIDGE TER EVANSTON, IL 60201
# 7607    810 WASHINGTON ST EVANSTON, IL 60202
# 11449     235 HARTREY AVE EVANSTON, IL 60202
# 560         732 RIDGE AVE EVANSTON, IL 60202
# 10514      2141 EWING AVE EVANSTON, IL 60201
# 15053     1827 BRUMMEL ST EVANSTON, IL 60202
# 4811         1408 LAKE ST EVANSTON, IL 60201
# 2516        944 DODGE AVE EVANSTON, IL 60202
# 13448  2307 ORRINGTON AVE EVANSTON, IL 60201
# 13803         815 REBA PL EVANSTON, IL 60202

# %%
## address column to numpy array for address list text file
address_list = adds_sml['addresses'].to_numpy()
address_list
# Out:
# array(['811 RIDGE TER EVANSTON, IL 60201',
#        '810 WASHINGTON ST EVANSTON, IL 60202',
#        '235 HARTREY AVE EVANSTON, IL 60202',
#        '732 RIDGE AVE EVANSTON, IL 60202',
#        '2141 EWING AVE EVANSTON, IL 60201',
#        '1827 BRUMMEL ST EVANSTON, IL 60202',
#        '1408 LAKE ST EVANSTON, IL 60201',
#        '944 DODGE AVE EVANSTON, IL 60202',
#        '2307 ORRINGTON AVE EVANSTON, IL 60201',
#        '815 REBA PL EVANSTON, IL 60202'], dtype=object)

# %% [markdown]
# # Save text file of addresses for property streetview api call

# %%
# un-comment to save

np.savetxt("static/data/raw/sample_TEST_address_list.txt", address_list, fmt='%5s')

# %% [markdown]
# # GRAB A SERIES OF STREET VIEW IMAGES FROM ADDRESSES PROVIDED

# %%
#this is the first part of the streetview, url up to the address, this url will return a 600x600px image
#pre="https://maps.googleapis.com/maps/api/streetview?size=600x600&amp;location="
pre="https://maps.googleapis.com/maps/api/streetview?size=600x600&location="
 
#this is the second part of the streetview url, the text variable below, includes the path to a text file containing one address per line
#the addresses in this text file will complete the URL needed to return a streetview image and provide the filename of each streetview image
text="static/data/raw/sample_TEST_address_list.txt"
 
#this is the third part of the url, needed after the address
#this is my API key, please replace the one below with your own (google 'google streetview api key'), thanks!
suf=f"&key={gkey}&fov=60"
 
#this is the directory that will store the streetview images
#this directory will be created if not present
dir=r"static/data/raw/locs/"
 
#checks if the dir variable (output path) above exists and creates it if it does not
if not os.path.exists(dir):
    os.makedirs(dir)
 
#opens the address list text file (from the 'text' variable defined above) in read mode ("r")
with open(text,"r") as text_file:
  #the variable 'lines' below creates a list of each address line in the source 'text' file
  addresses = [line.rstrip('\n') for line in open(text)]

    
#   print("THE CONTENTS OF THE TEXT FILE:\n"+str(lines))
  #start a loop through the 'lines' list
  for i in range(len(addresses)):
    
    #string clean-up to get rid of commas in the url and filename
    aid = addressdf['id'][i]
    print(addressdf['id'][i])
    
    ln = addresses[i].replace(" " , "+")

#     ln = addresses[i].split(" ")[1:].replace(" " , "+")
#     print("CLEANED UP ADDRESS LINE:\n"+ln)

    # creates the url that will be passed to the url reader, this creates the full, valid, url that will return a google streetview image for each address in the address text file
    URL = pre+ln+suf
#     print("URL FOR STREETVIEW IMAGE:\n"+URL)
    #creates the filename needed to save each address's streetview image locally
    filename = os.path.join(dir, "_" + str(aid)+".jpg")
#     print("OUTPUT FILENAME:\n"+filename)
    #you can run this up to this line in the python command line to see what each step does
    #final step, fetches and saves the streetview image for each address using the url created in the previous steps
    urllib.request.urlretrieve(URL, filename)

# %% [markdown]
# # Optional Latitude and Longitude API call

# %%
# # create a params dict that will be updated with new city each iteration
# params = {
#     'size': '640x640', # max 640x640 pixels
#     'heading': '90',
#     'location': '',
#     'pitch': '-0.76',
#     'fov': 120,
#     'key': gkey
# }

# # Loop through the cities_pd and run a lat/long search for each city
# geometry_list = adds_sml['geometry'].to_list()
# i = 0
# for latlong in geometry_list[50:60]:
    
#     # update address key value
#     params['location'] = latlong
    
#     # Create a results object
# #     results = google_streetview.api.results(params)
#     results = google_streetview.api.results([params])
    
    
     

#     # Download images to directory 'downloads'
#     results.download_links(f"static/data/raw/geo{i}",)
#     old_file_name = f"static/data/raw/geo{i}/gsv_0.jpg"
#     new_file_name = f"static/data/raw/geo{i}/gsv_{i}.jpg"

#     os.rename(old_file_name, new_file_name)
    
#     #pull .jpeg into main folder rename .jpeg{i}
    
#     i += 1
    
#     # Wait for 1 second
#     #time.sleep(1)

# %%
# # *** ORIGINAL PULL THAT WORKS ***
# # Define parameters for street view api
# params = [{
#     'size': '600x300', # max 640x640 pixels
#     'location': '41.9295582,-87.7159139',
#     'heading': '90',
#     'pitch': '-0.76',
#     'key': gkey
# }]

# # Create a results object
# results = google_streetview.api.results(params)

# # Download images to directory 'downloads'
# results.download_links('static/data/raw')
